# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
with open('datasets/startup_funding.csv', encoding='utf8') as file_obj:
    file_data=csv.DictReader(file_obj, skipinitialspace=True)
    investors=[]
    for row in file_data:
        if not ('Undisclosed' in row['InvestorsName'] or 'undisclosed' in row['InvestorsName']):
            for i in row['InvestorsName'].split(','):
                investors.append(i.strip())
    dic=dict()
    for i in investors:
        if i in dic.keys():
            dic[i]+=1
        else:
            dic[i]=1
    x=[]
    y=[]
    for i in dic.keys():
        if i!='':
            x.append(i)
            y.append(dic[i])
    np_x=np.array(x)
    np_y=np.array(y)

    np_x=np_x[np.argsort(np_y)]
    np_y=np.sort(np_y)
    
    np_y=np_y[len(np_y)-1:len(np_y)-1-5:-1]
    np_x=np_x[len(np_x)-1:len(np_x)-1-5:-1]
    
    plt.bar(np_x, np_y, color='orange')
    plt.xticks(rotation=45, size=12)
    plt.title('Investors V/S No. of times invested', size=16)
    plt.xlabel('Investors----->', size=16)
    plt.ylabel('No. of times invested----->', size=16)
    plt.show()
    
    for i in range(len(np_x)):
        print(np_x[i], np_y[i])
# Out:
# Sequoia Capital 64
# Accel Partners 52
# Kalaari Capital 44
# SAIF Partners 41
# Indian Angel Network 40
